# %%
# Import the world!
import os
import csv
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import random
import pandas as pd
import numpy as np

# %% [markdown]
# ## Part Two : Entering links to pick data

# %%
csv = './Career_Links_bizint.csv'
df = pd.read_csv(csv)

# %%
df.head()
# Out:
#    Unnamed: 0                                              Links      Region
# 0           0  https://www.mycareersfuture.sg/job/senior-busi...     Central
# 1           1  https://www.mycareersfuture.sg/job/assistant-m...       South
# 2           2  https://www.mycareersfuture.sg/job/data-analys...  Islandwide
# 3           3  https://www.mycareersfuture.sg/job/sap-pm-maxi...  Islandwide
# 4           4  https://www.mycareersfuture.sg/job/business-in...     Central

# %%
# Opening the driver
driver = webdriver.Chrome('/Users/paklun/Desktop/materials-master/projects/project-4/chromedriver')

# Setting up lists
company=[]
title=[]
employment=[]
seniority=[]
industry=[]
salary=[]
payment=[]
description=[]
requirements=[]
count=0

# Looping through links to scrape data, impute Nan if error

for x in df.Links:
    driver.get(x)
    count +=1
    sleep(random.randint(4,6))
    print('Currently Scraping Link No.',count)
    
    try:
        company.append(driver.find_element_by_name('company').text)
    except:
        company.append(np.nan)
    try:
        title.append(driver.find_element_by_id('job_title').text)
    except:
        title.append(np.nan)    
    try:
        employment.append(driver.find_element_by_id('employment_type').text)
    except:
        employment.append(np.nan)
    try:
        seniority.append(driver.find_element_by_id('seniority').text)
    except:
        seniority.append(np.nan)
    try:
        industry.append(driver.find_element_by_id('job-categories').text)
    except:
        industry.append(np.nan)
    try:
        salary.append(driver.find_element_by_class_name('lh-solid').text)
    except:
        salary.append(np.nan)
    try:
        payment.append(driver.find_element_by_class_name('salary_type').text)
    except:
        payment.append(np.nan)      
    try:
        description.append(driver.find_element_by_id('job_description').text)
    except:
        description.append(np.nan)
    try:
        requirements.append(driver.find_element_by_id('requirements').text)
    except:
        requirements.append(np.nan)
    
    if count%10==0:
        data = pd.DataFrame({'Company':company,'Title':title,'Employment Type':employment,'Seniority':seniority,'Industry':industry,'Salary':salary,'Payment':payment,'Description':description, 'Requirements':requirements })
        result = pd.concat([df,data], axis=1,sort=False)
        result.to_csv('Career_Database_bizint.csv')
        print('Savepoint:',count)
# Out:
# Currently Scraping Link No. 1
# Currently Scraping Link No. 2
# Currently Scraping Link No. 3
# Currently Scraping Link No. 4
# Currently Scraping Link No. 5
# Currently Scraping Link No. 6
# Currently Scraping Link No. 7
# Currently Scraping Link No. 8
# Currently Scraping Link No. 9
# Currently Scraping Link No. 10
# Savepoint: 10
# Currently Scraping Link No. 11
# Currently Scraping Link No. 12
# Currently Scraping Link No. 13
# Currently Scraping Link No. 14
# Currently Scraping Link No. 15
# Currently Scraping Link No. 16
# Currently Scraping Link No. 17
# Currently Scraping Link No. 18
# Currently Scraping Link No. 19
# Currently Scraping Link No. 20
# Savepoint: 20
# Currently Scraping Link No. 21
# Currently Scraping Link No. 22
# Currently Scraping Link No. 23
# Currently Scraping Link No. 24
# Currently Scraping Link No. 25
# Currently Scraping Link No. 26
# Currently Scraping Link No. 27
# Currently Scraping Link No. 28
# Currently Scraping Link No. 29
# Currently Scraping Link No. 30
# Savepoint: 30
# Currently Scraping Link No. 31
# Currently Scraping Link No. 32
# Currently Scraping Link No. 33
# Currently Scraping Link No. 34
# Currently Scraping Link No. 35
# Currently Scraping Link No. 36
# Currently Scraping Link No. 37
# Currently Scraping Link No. 38
# Currently Scraping Link No. 39
# Currently Scraping Link No. 40
# Savepoint: 40
# Currently Scraping Link No. 41
# Currently Scraping Link No. 42
# Currently Scraping Link No. 43
# Currently Scraping Link No. 44
# Currently Scraping Link No. 45
# Currently Scraping Link No. 46
# Currently Scraping Link No. 47
# Currently Scraping Link No. 48
# Currently Scraping Link No. 49
# Currently Scraping Link No. 50
# Savepoint: 50
# Currently Scraping Link No. 51
# Currently Scraping Link No. 52
# Currently Scraping Link No. 53
# Currently Scraping Link No. 54
# Currently Scraping Link No. 55
# Currently Scraping Link No. 56
# Currently Scraping Link No. 57
# Currently Scraping Link No. 58
# Currently Scraping Link No. 59
# Currently Scraping Link No. 60
# Savepoint: 60
# Currently Scraping Link No. 61
# Currently Scraping Link No. 62
# Currently Scraping Link No. 63
# Currently Scraping Link No. 64
# Currently Scraping Link No. 65
# Currently Scraping Link No. 66
# Currently Scraping Link No. 67
# Currently Scraping Link No. 68
# Currently Scraping Link No. 69
# Currently Scraping Link No. 70
# Savepoint: 70
# Currently Scraping Link No. 71
# Currently Scraping Link No. 72
# Currently Scraping Link No. 73
# Currently Scraping Link No. 74
# Currently Scraping Link No. 75
# Currently Scraping Link No. 76
# Currently Scraping Link No. 77
# Currently Scraping Link No. 78
# Currently Scraping Link No. 79
# Currently Scraping Link No. 80
# Savepoint: 80
# Currently Scraping Link No. 81
# Currently Scraping Link No. 82
# Currently Scraping Link No. 83
# Currently Scraping Link No. 84
# Currently Scraping Link No. 85
# Currently Scraping Link No. 86
# Currently Scraping Link No. 87
# Currently Scraping Link No. 88
# Currently Scraping Link No. 89
# Currently Scraping Link No. 90
# Savepoint: 90
# Currently Scraping Link No. 91
# Currently Scraping Link No. 92
# Currently Scraping Link No. 93
# Currently Scraping Link No. 94
# Currently Scraping Link No. 95
# Currently Scraping Link No. 96
# Currently Scraping Link No. 97
# Currently Scraping Link No. 98
# Currently Scraping Link No. 99
# Currently Scraping Link No. 100
# Savepoint: 100

# %%
data = pd.DataFrame({'Company':company,'Title':title,'Employment Type':employment,'Seniority':seniority,'Industry':industry,'Salary':salary,'Payment':payment,'Description':description, 'Requirements':requirements })

# %%
data
# Out:
#                                               Company  \
# 0                      STREETSINE SINGAPORE PTE. LTD.
# 1                  OAKWOOD WORLDWIDE (ASIA) PTE. LTD.
# 2     INTERNATIONAL SOS TECHNOLOGY SERVICES PTE. LTD.
# 3               BLUE OCEAN SYSTEMS INFOTECH PTE. LTD.
# 4         DREAMSCAPE NETWORKS INTERNATIONAL PTE. LTD.
# 5                         GRABTAXI HOLDINGS PTE. LTD.
# 6              ROCHE DIAGNOSTICS ASIA PACIFIC PTE LTD
# 7           TECHCOM SOLUTIONS & CONSULTANCY PTE. LTD.
# 8                   R SYSTEMS (SINGAPORE) PTE LIMITED
# 9                                 COMPANY UNDISCLOSED
# 10                                COMPANY UNDISCLOSED
# 11                      GOOGLE ASIA PACIFIC PTE. LTD.
# 12     MANPOWER STAFFING SERVICES (SINGAPORE) PTE LTD
# 13                   WIPRO LIMITED (SINGAPORE BRANCH)
# 14                                COMPANY UNDISCLOSED
# 15               LAMINAAR AVIATION INFOTECH PTE. LTD.
# 16      TURNER BROADCASTING SALES SOUTHEAST ASIA, INC
# 17                            SINGAPORE POWER LIMITED
# 18                            SINGAPORE POWER LIMITED
# 19                       SABRE ASIA PACIFIC PTE. LTD.
# 20             WILHELMSEN SHIPS SERVICE (S) PTE. LTD.
# 21                           FIXED & MOBILE PTE. LTD.
# 22                                COMPANY UNDISCLOSED
# 23                       INFOSYS CONSULTING PTE. LTD.
# 24                JABIL CIRCUIT (SINGAPORE) PTE. LTD.
# 25                    ICON CONSULTING-GROUP PTE. LTD.
# 26                            STANDARD CHARTERED BANK
# 27                     STREETSINE SINGAPORE PTE. LTD.
# 28            COCA-COLA SINGAPORE BEVERAGES PTE. LTD.
# 29                          BRINK'S SINGAPORE PTE LTD
# ..                                                ...
# 70              UNIMAS CONSULTING SOLUTIONS PTE. LTD.
# 71                          NINJA LOGISTICS PTE. LTD.
# 72      AMAZON WEB SERVICES SINGAPORE PRIVATE LIMITED
# 73                           CPM CONSULTING PTE. LTD.
# 74                             APAR INNOSYS PTE. LTD.
# 75                           CPM CONSULTING PTE. LTD.
# 76                 SAMSUNG SDS ASIA PACIFIC PTE. LTD.
# 77                   ZALORA SOUTH EAST ASIA PTE. LTD.
# 78                                      IKANO PTE LTD
# 79      AMAZON WEB SERVICES SINGAPORE PRIVATE LIMITED
# 80   MIDEA ELECTRIC TRADING (SINGAPORE) CO. PTE. LTD.
# 81                     QATAR AIRWAYS GROUP (Q.C.S.C.)
# 82                        APAR TECHNOLOGIES PTE. LTD.
# 83                     MONEYSMART SINGAPORE PTE. LTD.
# 84                 ANOTECH ENERGY SINGAPORE PTE. LTD.
# 85                   ZALORA SOUTH EAST ASIA PTE. LTD.
# 86                 ANOTECH ENERGY SINGAPORE PTE. LTD.
# 87                   ZALORA SOUTH EAST ASIA PTE. LTD.
# 88                            D2X EXPERTISE PTE. LTD.
# 89                           ADECCO PERSONNEL PTE LTD
# 90  BOEHRINGER INGELHEIM ANIMAL HEALTH SINGAPORE P...
# 91                           SINGAPORE LAND AUTHORITY
# 92                     STREETSINE SINGAPORE PTE. LTD.
# 93                                                NaN
# 94                                COMPANY UNDISCLOSED
# 95              HAYS SPECIALIST RECRUITMENT PTE. LTD.
# 96               BACKOFFICE ASSOCIATES ASIA PTE. LTD.
# 97               BACKOFFICE ASSOCIATES ASIA PTE. LTD.
# 98                           FIXED & MOBILE PTE. LTD.
# 99                                COMPANY UNDISCLOSED
#
#                                                 Title  \
# 0                             Senior Business Analyst
# 1   Assistant Manager, Operations Performance Mana...
# 2                                        Data Analyst
# 3                                       SAP PM MAXIMO
# 4                     Business Intelligence Developer
# 5                                        Data Analyst
# 6                            Controller, Asia Pacific
# 7                                 SAP BODS Consultant
# 8                            Datawarehouse Consultant
# 9                                  Solution architect
# 10                                            Manager
# 11  Data Science Lead, Large Customer Sales - Sing...
# 12                               SharePoint Developer
# 13                                    Project Manager
# 14                                    General Manager
# 15                       Lead - Business Intelligence
# 16                    Engineer, Business Intelligence
# 17                                     Data Scientist
# 18                              Senior Data Scientist
# 19                                HR Business Partner
# 20                                  Financial Analyst
# 21                           Head of Data Engineering
# 22                                          Developer
# 23                        Business Analyst Consultant
# 24                                     Data Scientist
# 25                                Analytics Architect
# 26                               Finance Manager, ITO
# 27                         Senior Database Specialist
# 28                                      Trade Analyst
# 29                        Sales cum Marketing Manager
# ..                                                ...
# 70                   Senior Consultant Data Analytics
# 71              Business Intelligence Project Manager
# 72                       Big Data Solutions Architect
# 73                               Associate Consultant
# 74                    Senior Datawarehouse Consultant
# 75                       Data Science Lead Consultant
# 76                                  Assistant Manager
# 77                         Junior Merchandise Planner
# 78                      Business Intelligence Analyst
# 79                 APAC Head of Enterprise Operations
# 80                   Senior Sales & Marketing Manager
# 81                    Regional Cargo Business Analyst
# 82                    Senior Datawarehouse Consultant
# 83                                     Data Team Lead
# 84  Senior MS Business Intelligence Software Engineer
# 85               Senior Business Intelligence Analyst
# 86         MS Business Intelligence Software Engineer
# 87               Senior Business Intelligence Analyst
# 88            Business Intelligence Analyst Developer
# 89            Business Intelligence Software Engineer
# 90  Customer Experience Manager, Regional Operativ...
# 91  Assistant Manager / Technical Manager, GeoSpat...
# 92                                Senior Data Analyst
# 93                                                NaN
# 94                                  Marketing Manager
# 95                      Business Intelligence Analyst
# 96                            Data Science Consultant
# 97                            Data Science Consultant
# 98                                      Data Engineer
# 99                           Digital Insights manager
#
#                     Employment Type  \
# 0                         Full Time
# 1                         Full Time
# 2                         Full Time
# 3                         Permanent
# 4                         Permanent
# 5                         Full Time
# 6                         Full Time
# 7               Contract, Full Time
# 8                         Full Time
# 9               Contract, Full Time
# 10                        Full Time
# 11                        Full Time
# 12              Contract, Full Time
# 13                        Permanent
# 14                        Full Time
# 15                        Full Time
# 16                        Permanent
# 17                        Full Time
# 18                        Full Time
# 19                        Full Time
# 20             Permanent, Full Time
# 21             Permanent, Full Time
# 22                        Full Time
# 23                        Full Time
# 24             Permanent, Full Time
# 25                        Permanent
# 26                        Full Time
# 27                        Full Time
# 28             Permanent, Full Time
# 29                        Permanent
# ..                              ...
# 70  Contract, Full Time, Internship
# 71             Permanent, Full Time
# 72                        Permanent
# 73                        Full Time
# 74                         Contract
# 75                        Permanent
# 76                        Permanent
# 77             Permanent, Full Time
# 78                        Permanent
# 79                        Full Time
# 80                        Full Time
# 81                        Permanent
# 82                         Contract
# 83                        Full Time
# 84                         Contract
# 85             Permanent, Full Time
# 86                         Contract
# 87             Permanent, Full Time
# 88             Permanent, Full Time
# 89              Contract, Full Time
# 90                        Full Time
# 91                        Full Time
# 92             Permanent, Full Time
# 93                              NaN
# 94                        Full Time
# 95   Permanent, Contract, Full Time
# 96                        Full Time
# 97                        Full Time
# 98                        Permanent
# 99                        Full Time
#
#                                             Seniority  \
# 0                                   Middle Management
# 1                                             Manager
# 2                                        Professional
# 3                                   Middle Management
# 4                                        Professional
# 5                                           Executive
# 6                                           Executive
# 7                                        Professional
# 8                                           Executive
# 9                                    Senior Executive
# 10                                            Manager
# 11                                          Executive
# 12                                          Executive
# 13                                       Professional
# 14         Senior Management, Professional, Executive
# 15                                       Professional
# 16                                          Executive
# 17                                       Professional
# 18                                  Middle Management
# 19                                   Senior Executive
# 20                                  Fresh/entry level
# 21                                  Senior Management
# 22                                          Executive
# 23                        Professional, Non-executive
# 24                                          Executive
# 25                                       Professional
# 26                         Middle Management, Manager
# 27                                  Middle Management
# 28                                          Executive
# 29                                            Manager
# ..                                                ...
# 70                                  Middle Management
# 71  Middle Management, Professional, Senior Executive
# 72                                       Professional
# 73                                  Fresh/entry level
# 74                                          Executive
# 75                                       Professional
# 76                     Professional, Senior Executive
# 77                                   Junior Executive
# 78                                  Middle Management
# 79                                  Senior Management
# 80               Manager, Executive, Senior Executive
# 81                                          Executive
# 82                                       Professional
# 83                                            Manager
# 84                                   Senior Executive
# 85                                       Professional
# 86                                          Executive
# 87                                       Professional
# 88                                       Professional
# 89                                          Executive
# 90                         Middle Management, Manager
# 91                                            Manager
# 92                            Professional, Executive
# 93                                                NaN
# 94                                            Manager
# 95                                   Junior Executive
# 96                                       Professional
# 97                                       Professional
# 98                                      Non-executive
# 99                                            Manager
#
#                                              Industry              Salary  \
# 0                              Information Technology      $4,000to$6,000
# 1                                         Hospitality                 NaN
# 2                              Information Technology      $6,000to$6,500
# 3                                          Consulting      $6,000to$7,000
# 4                              Information Technology      $5,000to$7,000
# 5                              Information Technology                 NaN
# 6                         Healthcare / Pharmaceutical      $5,000to$9,000
# 7         Banking and Finance, Information Technology      $5,000to$6,500
# 8                              Information Technology      $6,000to$7,000
# 9                              Information Technology      $7,000to$8,500
# 10                             Information Technology    $14,000to$15,000
# 11                             Information Technology     $7,700to$15,400
# 12                             Information Technology     $6,000to$12,000
# 13                             Information Technology     $8,500to$10,500
# 14                                 General Management    $14,000to$15,000
# 15                             Information Technology     $8,000to$12,000
# 16                             Information Technology    $68,040to$83,160
# 17                             Information Technology      $4,000to$8,000
# 18                             Information Technology     $8,000to$14,000
# 19                                    Human Resources   $84,000to$144,000
# 20                   Accounting / Auditing / Taxation      $3,000to$4,500
# 21                             Information Technology     $8,000to$11,000
# 22                             Information Technology     $9,500to$12,000
# 23                                         Consulting     $5,500to$10,000
# 24              Information Technology, Manufacturing      $3,000to$6,000
# 25                             Information Technology    $15,000to$20,000
# 26  Accounting / Auditing / Taxation, Banking and ...     $7,500to$10,000
# 27                             Information Technology      $4,000to$6,000
# 28                       Marketing / Public Relations      $2,400to$3,300
# 29      Marketing / Public Relations , Sales / Retail                 NaN
# ..                                                ...                 ...
# 70                                         Consulting      $6,000to$9,000
# 71                              Professional Services      $6,000to$9,500
# 72                             Information Technology  $130,000to$250,000
# 73                             Information Technology      $3,000to$4,000
# 74                             Information Technology      $6,000to$8,000
# 75                             Information Technology      $7,000to$9,000
# 76                             Information Technology      $3,500to$7,000
# 77                         Purchasing / Merchandising      $3,000to$4,000
# 78           Accounting / Auditing / Taxation, Others                 NaN
# 79                             Information Technology    $20,000to$30,000
# 80      Marketing / Public Relations , Sales / Retail      $5,000to$6,500
# 81                                   Travel / Tourism      $3,500to$5,500
# 82                             Information Technology      $6,000to$8,000
# 83                             Information Technology     $7,000to$12,000
# 84                             Information Technology                 NaN
# 85                                             Others      $4,000to$7,000
# 86                             Information Technology                 NaN
# 87                   Logistics / Supply Chain, Others      $5,000to$7,000
# 88         Customer Service, Logistics / Supply Chain      $4,000to$9,000
# 89                             Information Technology      $5,000to$7,500
# 90           Consulting , Healthcare / Pharmaceutical     $7,400to$13,320
# 91     Information Technology, Public / Civil Service      $4,000to$6,800
# 92                             Information Technology      $4,000to$8,000
# 93                                                NaN                 NaN
# 94                       Marketing / Public Relations     $5,000to$10,000
# 95                             Information Technology      $4,000to$5,000
# 96                             Information Technology      $7,000to$9,000
# 97                             Information Technology      $6,000to$8,000
# 98                             Information Technology      $4,000to$7,000
# 99                                             Others                 NaN
#
#      Payment                                        Description  \
# 0    Monthly  Roles & Responsibilities\nSenior Business Anal...
# 1             Roles & Responsibilities\nWe are looking for a...
# 2    Monthly  Roles & Responsibilities\nIn our Digital Innov...
# 3    Monthly  Roles & Responsibilities\nat least one Full li...
# 4    Monthly  Roles & Responsibilities\nAs a Business Intell...
# 5             Roles & Responsibilities\nGet to know our Team...
# 6    Monthly  Roles & Responsibilities\nWho we are\nAt Roche...
# 7    Monthly  Roles & Responsibilities\nSeeking a skilled an...
# 8    Monthly  Roles & Responsibilities\nExperience working w...
# 9    Monthly  Roles & Responsibilities\n·         Total Expe...
# 10   Monthly  Roles & Responsibilities\nCandidate should hav...
# 11   Monthly  Roles & Responsibilities\nCompany overview:\nG...
# 12   Monthly  Roles & Responsibilities\nAs a SharePoint Deve...
# 13   Monthly  Roles & Responsibilities\nPosition Responsibil...
# 14   Monthly  Roles & Responsibilities\nCandidate should hav...
# 15   Monthly  Roles & Responsibilities\nDesign and architect...
# 16  Annually  Roles & Responsibilities\nThe Business Intelli...
# 17   Monthly  Roles & Responsibilities\nWhy Work for Us\nWe ...
# 18   Monthly  Roles & Responsibilities\nWhy Work for Us\nWe ...
# 19  Annually  Roles & Responsibilities\nSabre is a leading t...
# 20   Monthly  Roles & Responsibilities\nReview and comment o...
# 21   Monthly  Roles & Responsibilities\nTransferTo operates ...
# 22   Monthly  Roles & Responsibilities\nDevelop, deliver and...
# 23   Monthly  Roles & Responsibilities\nResponsibility\nSupp...
# 24   Monthly  Roles & Responsibilities\nJOB SUMMARY\nThe Dat...
# 25   Monthly  Roles & Responsibilities\nSolution Architect\n...
# 26   Monthly  Roles & Responsibilities\nKey Responsibilities...
# 27   Monthly  Roles & Responsibilities\nDescription: Senior ...
# 28   Monthly  Roles & Responsibilities\nResponsible for prov...
# 29            Roles & Responsibilities\nBRINK'S SINGAPORE PT...
# ..       ...                                                ...
# 70   Monthly  Roles & Responsibilities\nBI/Data Analytics / ...
# 71   Monthly  Roles & Responsibilities\nNinja Van is on a mi...
# 72  Annually  Roles & Responsibilities\nAmazon Web Services ...
# 73   Monthly  Roles & Responsibilities\nCPM Consulting, a Ba...
# 74   Monthly  Roles & Responsibilities\nPrepare Test cases f...
# 75   Monthly  Roles & Responsibilities\nPrimary Responsibili...
# 76   Monthly  Roles & Responsibilities\nCompile complex data...
# 77   Monthly  Roles & Responsibilities\nWe are looking for a...
# 78            Roles & Responsibilities\nABOUT THE JOB\nWe wa...
# 79   Monthly  Roles & Responsibilities\nAWS is one of Amazon...
# 80   Monthly  Roles & Responsibilities\nManager of Sales & M...
# 81   Monthly  Roles & Responsibilities\nAbout the Job:\nAs a...
# 82   Monthly  Roles & Responsibilities\nPrepare Test cases f...
# 83   Monthly  Roles & Responsibilities\nAbout the job\nMoney...
# 84            Roles & Responsibilities\nAn exciting opportun...
# 85   Monthly  Roles & Responsibilities\nIn this role, the Se...
# 86            Roles & Responsibilities\n  Position\n  The de...
# 87   Monthly  Roles & Responsibilities\nIn this role, the Se...
# 88   Monthly  Roles & Responsibilities\nWe are looking for a...
# 89   Monthly  Roles & Responsibilities\nMain responsibilitie...
# 90   Monthly  Roles & Responsibilities\nTranslate Customer E...
# 91   Monthly  Roles & Responsibilities\nAssistant Manager/ T...
# 92   Monthly  Roles & Responsibilities\nWe are currently loo...
# 93       NaN                                                NaN
# 94   Monthly  Roles & Responsibilities\nPRIMARY FUNCTION\nPa...
# 95   Monthly  Roles & Responsibilities\nThis consultancy com...
# 96   Monthly  Roles & Responsibilities\nPrimary Responsibili...
# 97   Monthly  Roles & Responsibilities\nPrimary Responsibili...
# 98   Monthly  Roles & Responsibilities\nTransferTo operates ...
# 99            Roles & Responsibilities\nReporting to the Res...
#
#                                          Requirements
# 0   Requirements\nRequirements:\nBachelor’s degree...
# 1   Requirements\nWHAT WE REQUIRE\nAt least a Bach...
# 2   Requirements\nEducation and Experience:\nBache...
# 3   Requirements\nat least one Full life cycle PM ...
# 4   Requirements\nmyYou should have:\nA degree in ...
# 5   Requirements\nThe must haves:\nA Bachelor's/Ma...
# 6   Requirements\nWho you are\nYou’re someone who ...
# 7   Requirements\nSeeking a skilled and experience...
# 8   Requirements\nGood experience in HADOOP IS REQ...
# 9   Requirements\nSound knowledge of SDLC, estimat...
# 10  Requirements\nJob Requirements:\nBachelor degr...
# 11  Requirements\nMinimum qualifications:\n- Bache...
# 12  Requirements\nProgramming in HTML5 with JavaSc...
# 13  Requirements\nBachelor’s degree required (mini...
# 14  Requirements\nBachelor degree in Business Econ...
# 15  Requirements\nProficiency in Data Visualizatio...
# 16  Requirements\nEssential\n1. 4+ years solid exp...
# 17  Requirements\nWhat You'll Need\nWe are looking...
# 18  Requirements\nWhat You'll Need\nWe are looking...
# 19  Requirements\nDesired Skills and Experience\nS...
# 20  Requirements\nACCA/CPA/Minimum Degree in Finan...
# 21  Requirements\nEssential Experience\nMore than ...
# 22  Requirements\n  Education and\nQualifications\...
# 23  Requirements\nFunctional Skills:\nStakeholder ...
# 24  Requirements\n●         Advanced Statistics, o...
# 25  Requirements\nDesired Skills:\nExcellent Custo...
# 26  Requirements\nKey Requirements\nDegree qualifi...
# 27  Requirements\nSpecific skills/experience:\nBac...
# 28  Requirements\nQualification Criteria\n•Minimum...
# 29  Requirements\nDegree holder in a related field...
# ..                                                ...
# 70  Requirements\nBI/Data Analytics / FP&A, Manage...
# 71  Requirements\nStrong communications skills\nAb...
# 72  Requirements\nBasic Qualifications: \nDeep und...
# 73  Requirements\nQualifications:\nEducational bac...
# 74  Requirements\nDegree in Statistics, Mathematic...
# 75  Requirements\nQualification:\nComputer Science...
# 76  Requirements\nBachelor's degree in Mathematics...
# 77  Requirements\nRequirements:\nEducated to Degre...
# 78  Requirements\nYOUR PROFILE \nYour knowledge, s...
# 79  Requirements\n· 7+ years of experience in fina...
# 80  Requirements\nExperience & Background\n3+ year...
# 81  Requirements\nAbout You:\nTo qualify for the r...
# 82  Requirements\nDegree in Statistics, Mathematic...
# 83  Requirements\nRequirements\n6+ years of profes...
# 84  Requirements\nQualifications and Profile\nTech...
# 85  Requirements\nMinimum Bachelor’s degree in a q...
# 86  Requirements\nQualifications and Profile\n  Ma...
# 87  Requirements\nMinimum Bachelor’s degree in a q...
# 88  Requirements\n5+ years of experience in busine...
# 89  Requirements\nThis position requires 5+ years ...
# 90  Requirements\nBusiness orientation and experie...
# 91                                                NaN
# 92  Requirements\nRequirements:\nMinimum 2 years o...
# 93                                                NaN
# 94  Requirements\nREQUIREMENT\nEducation\nUniversi...
# 95  Requirements\nExcellent communication and stak...
# 96  Requirements\nCandidate should possess good so...
# 97  Requirements\nCandidate should possess good so...
# 98  Requirements\nEssential Experience\nMore than ...
# 99  Requirements\nEssential\n1. Experience in  a m...
#
# [100 rows x 9 columns]

# %%
# result = pd.concat([df,data], axis=1,sort=False)

# %%
# result.to_csv('Career_Database_bizint.csv')

# %%
# Closes the driver
driver.close()
